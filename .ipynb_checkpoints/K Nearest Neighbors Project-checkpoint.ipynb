# %% [markdown]
# # K Nearest Neighbors Project

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as matplot
import seaborn as sns

# %matplotlib inline

sns.set(style = 'darkgrid', palette = 'muted')
matplot.set_cmap(cmap = 'coolwarm')

# %% [markdown]
# ## Get the Data
# ** Read the 'KNN_Project_Data csv file into a dataframe **

# %%
df = pd.read_csv('KNN_Project_Data')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
# XVPM            1000 non-null float64
# GWYH            1000 non-null float64
# TRAT            1000 non-null float64
# TLLZ            1000 non-null float64
# IGGA            1000 non-null float64
# HYKR            1000 non-null float64
# EDFS            1000 non-null float64
# GUUB            1000 non-null float64
# MGJM            1000 non-null float64
# JHZC            1000 non-null float64
# TARGET CLASS    1000 non-null int64
# dtypes: float64(10), int64(1)
# memory usage: 86.0 KB

# %% [markdown]
# **Check the head of the dataframe.**

# %%
df.head()
# Out:
#           XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0  1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1  1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2  1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3  1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4  1018.340526  1313.679056   950.622661  724.742174   843.065903
#
#           HYKR         EDFS        GUUB         MGJM         JHZC  \
# 0  1618.870897  2147.641254  330.727893  1494.878631   845.136088
# 1  2084.107872   853.404981  447.157619  1193.032521   861.081809
# 2  2552.355407   818.676686  845.491492  1968.367513  1647.186291
# 3   685.666983   852.867810  341.664784  1154.391368  1450.935357
# 4  1370.554164   905.469453  658.118202   539.459350  1899.850792
#
#    TARGET CLASS
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0

# %% [markdown]
# # EDA
#
# Since this data is artificial, we'll just do a large pairplot with seaborn.
#
# **Use seaborn on the dataframe to create a pairplot with the hue indicated by the TARGET CLASS column.**

# %%
sns.pairplot(data = df, hue = 'TARGET CLASS')

# %% [markdown]
# # Standardize the Variables
#
# Time to standardize the variables.
#
# ** Import StandardScaler from Scikit learn.**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ** Create a StandardScaler() object called scaler.**

# %%
scaler = StandardScaler()

# %% [markdown]
# ** Fit scaler to the features.**

# %%
scaler.fit(X = df.drop('TARGET CLASS', axis = 1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# **Use the .transform() method to transform the features to a scaled version.**

# %%
scaled_features = scaler.transform(df.drop('TARGET CLASS', axis = 1))

# %% [markdown]
# **Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.**

# %%
scaled_features_df = pd.DataFrame(data = scaled_features, columns = df.columns[:-1])
scaled_features_df.head()
# Out:
#        XVPM      GWYH      TRAT      TLLZ      IGGA      HYKR      EDFS  \
# 0  1.568522 -0.443435  1.619808 -0.958255 -1.128481  0.138336  0.980493
# 1 -0.112376 -1.056574  1.741918 -1.504220  0.640009  1.081552 -1.182663
# 2  0.660647 -0.436981  0.775793  0.213394 -0.053171  2.030872 -1.240707
# 3  0.011533  0.191324 -1.433473 -0.100053 -1.507223 -1.753632 -1.183561
# 4 -0.099059  0.820815 -0.904346  1.609015 -0.282065 -0.365099 -1.095644
#
#        GUUB      MGJM      JHZC
# 0 -0.932794  1.008313 -1.069627
# 1 -0.461864  0.258321 -1.041546
# 2  1.149298  2.184784  0.342811
# 3 -0.888557  0.162310 -0.002793
# 4  0.391419 -1.365603  0.787762

# %% [markdown]
# # Train Test Split
#
# **Use train_test_split to split your data into a training set and a testing set.**

# %%
XTrain, XTest, yTrain, yTest = train_test_split(scaled_features_df, df['TARGET CLASS'], test_size = 0.3)

# %% [markdown]
# # Using KNN
#
# **Import KNeighborsClassifier from scikit learn.**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Create a KNN model instance with n_neighbors=1**

# %%
knn = KNeighborsClassifier(n_neighbors = 1)

# %% [markdown]
# **Fit this KNN model to the training data.**

# %%
knn.fit(X = XTrain, y = yTrain)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %% [markdown]
# # Predictions and Evaluations
# Let's evaluate our KNN model!

# %% [markdown]
# **Use the predict method to predict values using your KNN model and X_test.**

# %%
predicitions = knn.predict(X = XTest)

# %% [markdown]
# ** Create a confusion matrix and classification report.**

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
conf_mat = pd.DataFrame(data = confusion_matrix(y_true = yTest, y_pred = predicitions), 
                        index = df['TARGET CLASS'].unique(), 
                        columns = df['TARGET CLASS'].unique())
conf_mat
# Out:
#      0    1
# 0  114   42
# 1   37  107

# %%
print(classification_report(y_true = yTest, y_pred = predicitions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.75      0.73      0.74       156
#           1       0.72      0.74      0.73       144
#
# avg / total       0.74      0.74      0.74       300

# %% [markdown]
# # Choosing a K Value
# Let's go ahead and use the elbow method to pick a good K Value!
#
# ** Create a for loop that trains various KNN models with different k values, then keep track of the error_rate for each of these models with a list. Refer to the lecture if you are confused on this step.**

# %%
error_rate = []

for i in range(1, 41):
    knn_i = KNeighborsClassifier(n_neighbors = i)
    knn_i.fit(X = XTrain, y = yTrain)
    pred_i = knn_i.predict(X = XTest)
    
    error_rate.append(np.mean(pred_i != yTest))

# %% [markdown]
# **Now create the following plot using the information from your for loop.**

# %%
matplot.figure(figsize = (12, 7))
matplot.plot(range(1, 41), error_rate, linestyle = '--', marker = 'o', markerfacecolor = 'red', markersize = 8)
matplot.xlabel("K Values")
matplot.ylabel('Error Rate')

for i in range(1, 41):
    matplot.annotate(text = round(error_rate[i-1], 2), xy = (i, error_rate[i-1]))

# %% [markdown]
# ## Retrain with new K Value
#
# **Retrain your model with the best K value (up to you to decide what you want) and re-do the classification report and the confusion matrix.**

# %%
knn = KNeighborsClassifier(n_neighbors=12)

knn.fit(XTrain,yTrain)
pred = knn.predict(XTest)

print('WITH K=30')
print('\n')
print(confusion_matrix(yTest,pred))
print('\n')
print(classification_report(yTest,pred))
# Out:
# WITH K=30
#
#
# [[130  26]
#  [ 30 114]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.81      0.83      0.82       156
#           1       0.81      0.79      0.80       144
#
# avg / total       0.81      0.81      0.81       300
