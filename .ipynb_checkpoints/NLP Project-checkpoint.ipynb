# %% [markdown]
# # Natural Language Processing Project
#
# Dataset: [Yelp Review Data Set from Kaggle](https://www.kaggle.com/c/yelp-recsys-2013).
#
# Each observation in this dataset is a review of a particular business by a particular user.
# <h3> Goal </h3>
#
# To predict the star rating given the review.

# %% [markdown]
# ## Imports
#  **Import the usual suspects. :) **

# %%
import numpy as np
import pandas as pd

import matplotlib as matplot
import seaborn as sns

# %matplotlib inline
sns.set(style = 'darkgrid', palette = 'muted')

# %% [markdown]
# ## The Data

# %%
yelp = pd.read_csv('yelp.csv')

# %% [markdown]
# ** Check the head, info , and describe methods on yelp.**

# %%
yelp.head()
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# 2  0hT2KtfLiobPvh6cDC8JQg     0       1      0
# 3  uZetl9T0NcROGOyFfughhg     1       2      0
# 4  vYmM4KTsC8ZfQBg-j5MWkw     0       0      0

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# business_id    10000 non-null object
# date           10000 non-null object
# review_id      10000 non-null object
# stars          10000 non-null int64
# text           10000 non-null object
# type           10000 non-null object
# user_id        10000 non-null object
# cool           10000 non-null int64
# useful         10000 non-null int64
# funny          10000 non-null int64
# dtypes: int64(4), object(6)
# memory usage: 781.3+ KB

# %%
yelp.describe()
# Out:
#               stars          cool        useful         funny   text_length
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.777500      0.876800      1.409300      0.701300    710.738700
# std        1.214636      2.067861      2.336647      1.907942    617.399827
# min        1.000000      0.000000      0.000000      0.000000      1.000000
# 25%        3.000000      0.000000      0.000000      0.000000    294.000000
# 50%        4.000000      0.000000      1.000000      0.000000    541.500000
# 75%        5.000000      1.000000      2.000000      1.000000    930.000000
# max        5.000000     77.000000     76.000000     57.000000   4997.000000

# %% [markdown]
# **Create a new column called "text length" which is the number of words in the text column.**

# %%
yelp['text_length'] = yelp['text'].apply(len)

# %% [markdown]
# # EDA
#
# Let's explore the data

# %%
facet_grid = sns.FacetGrid(data = yelp, col = 'stars', palette = 'muted')
facet_grid.map(sns.distplot, 'text_length', kde = False)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
sns.boxplot(x = 'stars', y = 'text_length', data = yelp, palette = 'muted')

# %%
sns.countplot(x = 'stars', data = yelp)

# %%
inc_cols = 'stars cool useful funny text_length'.split()
inc_cols
# Out:
# ['stars', 'cool', 'useful', 'funny', 'text_length']

# %%
grpby_stars = yelp[inc_cols].groupby(by = 'stars')
grpby_stars_mean_df = pd.DataFrame(data = grpby_stars.mean(), columns = inc_cols[1: ])
grpby_stars_mean_df
# Out:
#            cool    useful     funny  text_length
# stars
# 1      0.576769  1.604806  1.056075   826.515354
# 2      0.719525  1.563107  0.875944   842.256742
# 3      0.788501  1.306639  0.694730   758.498289
# 4      0.954623  1.395916  0.670448   712.923142
# 5      0.944261  1.381780  0.608631   624.999101

# %%
grpby_stars_mean_df.corr()
# Out:
#                  cool    useful     funny  text_length
# cool         1.000000 -0.743329 -0.944939    -0.857664
# useful      -0.743329  1.000000  0.894506     0.699881
# funny       -0.944939  0.894506  1.000000     0.843461
# text_length -0.857664  0.699881  0.843461     1.000000

# %%
sns.heatmap(data = grpby_stars_mean_df.corr(), cmap = 'coolwarm', annot = True)

# %% [markdown]
# ## NLP Classification
#
# <b> Analyzing reviews with 1 and 5 star rating </b>

# %%
df = yelp[(yelp['stars'] == 1) | (yelp['stars'] == 5)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4086 entries, 0 to 9999
# Data columns (total 11 columns):
# business_id    4086 non-null object
# date           4086 non-null object
# review_id      4086 non-null object
# stars          4086 non-null int64
# text           4086 non-null object
# type           4086 non-null object
# user_id        4086 non-null object
# cool           4086 non-null int64
# useful         4086 non-null int64
# funny          4086 non-null int64
# text_length    4086 non-null int64
# dtypes: int64(5), object(6)
# memory usage: 383.1+ KB

# %% [markdown]
# ** Create two objects X and y. X will be the 'text' column of yelp_class and y will be the 'stars' column of yelp_class. (Your features and target/labels)**

# %%
X = df['text']
y = df['stars']

# %% [markdown]
# <b> Custom Analyzer to remove the punctuations, stopwords

# %%
import nltk

# %%
#download stopwords corpus
nltk.download_shell()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %%
import string

# %%
from nltk.corpus import stopwords

# %%
def text_preprocessor(item):
    """
        Method removes the punctuation marks and stopwords from item string.
        Returns list of meaningful words from item string.
    """
    no_punctuation = [char for char in item if char not in string.punctuation]
    no_punctuation = ''.join(no_punctuation)
    return [word for word in no_punctuation.split() if word not in stopwords.words('english')]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vectorizer = CountVectorizer(analyzer = text_preprocessor)
bow_tranformer = count_vectorizer.fit(X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-298a1b95879f> in <module>
#       1 count_vectorizer = CountVectorizer(analyzer = text_preprocessor)
# ----> 2 bow_tranformer = count_vectorizer.fit(X)
#
# /anaconda3/envs/Python_for_DataScience/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#     976         self
#     977         """
# --> 978         self.fit_transform(raw_documents)
#     979         return self
#     980
#
# /anaconda3/envs/Python_for_DataScience/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1010
#    1011         vocabulary, X = self._count_vocab(raw_documents,
# -> 1012                                           self.fixed_vocabulary_)
#    1013
#    1014         if self.binary:
#
# /anaconda3/envs/Python_for_DataScience/lib/python3.6/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     920         for doc in raw_documents:
#     921             feature_counter = {}
# --> 922             for feature in analyze(doc):
#     923                 try:
#     924                     feature_idx = vocabulary[feature]
#
# <ipython-input-29-96cb8fc5bc45> in text_preprocessor(item)
#       6     no_punctuation = [char for char in item if char not in string.punctuation]
#       7     no_punctuation = ''.join(no_punctuation)
# ----> 8     return [word.lower() for word in no_punctuation.split() if word not in stopwords.words('english')]
#
# <ipython-input-29-96cb8fc5bc45> in <listcomp>(.0)
#       6     no_punctuation = [char for char in item if char not in string.punctuation]
#       7     no_punctuation = ''.join(no_punctuation)
# ----> 8     return [word.lower() for word in no_punctuation.split() if word not in stopwords.words('english')]
#
# /anaconda3/envs/Python_for_DataScience/lib/python3.6/site-packages/nltk/corpus/reader/wordlist.py in words(self, fileids, ignore_lines_startswith)
#      20     """
#      21     def words(self, fileids=None, ignore_lines_startswith='\n'):
# ---> 22         return [line for line in line_tokenize(self.raw(fileids))
#      23                 if not line.startswith(ignore_lines_startswith)]
#      24
#
# /anaconda3/envs/Python_for_DataScience/lib/python3.6/site-packages/nltk/tokenize/simple.py in line_tokenize(text, blanklines)
#     136
#     137 def line_tokenize(text, blanklines='discard'):
# --> 138     return LineTokenizer(blanklines).tokenize(text)
#
# /anaconda3/envs/Python_for_DataScience/lib/python3.6/site-packages/nltk/tokenize/simple.py in tokenize(self, s)
#     114         # If requested, strip off blank lines.
#     115         if self._blanklines == 'discard':
# --> 116             lines = [l for l in lines if l.rstrip()]
#     117         elif self._blanklines == 'discard-eof':
#     118             if lines and not lines[-1].strip():
#
# /anaconda3/envs/Python_for_DataScience/lib/python3.6/site-packages/nltk/tokenize/simple.py in <listcomp>(.0)
#     114         # If requested, strip off blank lines.
#     115         if self._blanklines == 'discard':
# --> 116             lines = [l for l in lines if l.rstrip()]
#     117         elif self._blanklines == 'discard-eof':
#     118             if lines and not lines[-1].strip():
#
# KeyboardInterrupt:

# %%
bow_tranformer.vocabulary_
# Out:
# {'My': 5666,
#  'wife': 26262,
#  'took': 24952,
#  'birthday': 10508,
#  'breakfast': 10846,
#  'excellent': 14371,
#  'The': 8144,
#  'weather': 26083,
#  'perfect': 20265,
#  'made': 18259,
#  'sitting': 23009,
#  'outside': 19808,
#  'overlooking': 19852,
#  'grounds': 15916,
#  'absolute': 9104,
#  'pleasure': 20585,
#  'Our': 6080,
#  'waitress': 25939,
#  'food': 15079,
#  'arrived': 9811,
#  'quickly': 21279,
#  'semibusy': 22595,
#  'Saturday': 7255,
#  'morning': 18966,
#  'It': 4460,
#  'looked': 18106,
#  'like': 17928,
#  'place': 20502,
#  'fills': 14805,
#  'pretty': 20911,
#  'earlier': 13903,
#  'get': 15541,
#  'better': 10442,
#  'Do': 2826,
#  'favor': 14679,
#  'Bloody': 1539,
#  'Mary': 5347,
#  'phenomenal': 20351,
#  'simply': 22964,
#  'best': 10431,
#  'Ive': 4474,
#  'ever': 14317,
#  'Im': 4367,
#  'sure': 24170,
#  'use': 25635,
#  'ingredients': 17047,
#  'garden': 15451,
#  'blend': 10581,
#  'fresh': 15244,
#  'order': 19712,
#  'amazing': 9513,
#  'While': 8814,
#  'EVERYTHING': 2973,
#  'menu': 18630,
#  'looks': 18108,
#  'I': 4296,
#  'white': 26225,
#  'truffle': 25218,
#  'scrambled': 22454,
#  'eggs': 14009,
#  'vegetable': 25728,
#  'skillet': 23040,
#  'tasty': 24459,
#  'delicious': 13146,
#  'came': 11211,
#  '2': 244,
#  'pieces': 20417,
#  'griddled': 15864,
#  'bread': 10835,
#  'absolutely': 9105,
#  'meal': 18521,
#  'complete': 12171,
#  'toast': 24882,
#  'Anyway': 1020,
#  'cant': 11259,
#  'wait': 25926,
#  'go': 15649,
#  'back': 10076,
#  'idea': 16812,
#  'people': 20241,
#  'give': 15588,
#  'bad': 10105,
#  'reviews': 21932,
#  'goes': 15665,
#  'show': 22859,
#  'please': 20580,
#  'everyone': 14330,
#  'They': 8162,
#  'probably': 20986,
#  'griping': 15889,
#  'something': 23317,
#  'faultthere': 14671,
#  'many': 18382,
#  'In': 4381,
#  'case': 11367,
#  'friend': 15269,
#  '550': 510,
#  'PM': 6164,
#  'past': 20099,
#  'Sunday': 7838,
#  'crowded': 12745,
#  'thought': 24744,
#  'evening': 14310,
#  'would': 26439,
#  'forever': 15128,
#  'seat': 22515,
#  'said': 22204,
#  'well': 26126,
#  'seated': 22516,
#  'girl': 15577,
#  'comes': 12068,
#  'seating': 22517,
#  'someone': 23314,
#  'else': 14054,
#  'We': 8757,
#  '552': 511,
#  'waiter': 25930,
#  'got': 15734,
#  'drink': 13774,
#  'orders': 19717,
#  'Everyone': 3148,
#  'pleasant': 20577,
#  'host': 16573,
#  'us': 25633,
#  'server': 22644,
#  'prices': 20932,
#  'good': 15687,
#  'placed': 20506,
#  'decided': 13046,
#  'wanted': 25981,
#  '602': 538,
#  'shared': 22728,
#  'baked': 10133,
#  'spaghetti': 23419,
#  'calzone': 11209,
#  'small': 23146,
#  'Heres': 4126,
#  'Beef': 1412,
#  'pizza': 20489,
#  'try': 25230,
#  'huge': 16697,
#  'smallest': 23149,
#  'one': 19609,
#  'personal': 20304,
#  '11': 62,
#  'Both': 1608,
#  'awesome': 10049,
#  'liked': 17930,
#  'sweetish': 24255,
#  'sauce': 22322,
#  'thats': 24642,
#  'box': 10787,
#  'part': 20062,
#  'take': 24358,
#  'home': 16481,
#  'door': 13654,
#  '642': 559,
#  'So': 7554,
#  'everything': 14333,
#  'great': 15829,
#  'reviewers': 21930,
#  'That': 8142,
#  'things': 24711,
#  'serious': 22634,
#  'issues': 17298,
#  'Rosie': 6994,
#  'Dakota': 2636,
#  'LOVE': 4871,
#  'Chaparral': 2077,
#  'Dog': 2835,
#  'Park': 6251,
#  'Its': 4472,
#  'convenient': 12388,
#  'surrounded': 24191,
#  'lot': 18132,
#  'paths': 20121,
#  'desert': 13241,
#  'xeriscape': 26488,
#  'baseball': 10247,
#  'fields': 14768,
#  'ballparks': 10156,
#  'lake': 17659,
#  'ducks': 13840,
#  'Scottsdale': 7294,
#  'Rec': 6813,
#  'Dept': 2744,
#  'wonderful': 26374,
#  'job': 17405,
#  'keeping': 17494,
#  'park': 20045,
#  'clean': 11843,
#  'shaded': 22698,
#  'You': 9006,
#  'find': 14821,
#  'trash': 25113,
#  'cans': 11258,
#  'poopypick': 20674,
#  'mitts': 18841,
#  'located': 18056,
#  'fenced': 14739,
#  'area': 9767,
#  'let': 17864,
#  'dogs': 13620,
#  'run': 22165,
#  'play': 20558,
#  'sniff': 23231,
#  'General': 3683,
#  'Manager': 5271,
#  'Scott': 7292,
#  'Petello': 6366,
#  'egg': 14000,
#  'Not': 5878,
#  'detail': 13288,
#  'assure': 9907,
#  'albeit': 9416,
#  'rare': 21367,
#  'speak': 23444,
#  'treat': 25140,
#  'guy': 16000,
#  'respect': 21842,
#  'state': 23723,
#  'Id': 4354,
#  'surprised': 24184,
#  'dont': 13647,
#  'walk': 25951,
#  'totally': 25001,
#  'satisfied': 22313,
#  'Like': 5002,
#  'always': 9498,
#  'say': 22364,
#  'Mistakes': 5541,
#  'inevitable': 17009,
#  'recover': 21517,
#  'important': 16880,
#  'Thanks': 8138,
#  'staff': 23637,
#  'Youve': 9016,
#  'customer': 12867,
#  'life': 17900,
#  'Drop': 2903,
#  'youre': 26572,
#  'drive': 13786,
#  'After': 843,
#  'ate': 9921,
#  'next': 19257,
#  'day': 12975,
#  'This': 8177,
#  'cute': 12876,
#  'little': 18016,
#  'green': 15850,
#  'building': 11014,
#  'may': 18507,
#  'gone': 15682,
#  'competely': 12146,
#  'unoticed': 25525,
#  'hadnt': 16030,
#  'driving': 13796,
#  'Palm': 6214,
#  'Rd': 6796,
#  'avoid': 10030,
#  'construction': 12325,
#  'waiting': 25935,
#  'turn': 25265,
#  'onto': 19642,
#  '16th': 185,
#  'Street': 7780,
#  'Grand': 3806,
#  'Opening': 6033,
#  'sign': 22926,
#  'caught': 11407,
#  'eye': 14525,
#  'yelping': 26538,
#  'soul': 23373,
#  'leaped': 17774,
#  'joy': 17434,
#  'A': 696,
#  'new': 19243,
#  'desolate': 13264,
#  'opened': 19660,
#  'put': 21223,
#  'easy': 13926,
#  'decor': 13068,
#  'smell': 23166,
#  'cleanliness': 11850,
#  'inside': 17098,
#  'ordered': 19713,
#  'dinner': 13405,
#  'two': 25306,
#  'loved': 18156,
#  'seeing': 22551,
#  'variety': 25709,
#  'poblano': 20615,
#  'peppers': 20255,
#  'mole': 18905,
#  'mahi': 18276,
#  'mushroomssomething': 19072,
#  'wrapped': 26451,
#  'banana': 10164,
#  'leaves': 17792,
#  'difficult': 13362,
#  'choose': 11736,
#  'far': 14632,
#  'La': 4882,
#  'Condesa': 2343,
#  'Shrimp': 7454,
#  'Burro': 1761,
#  'Baja': 1306,
#  'Sur': 7867,
#  'Dogfish': 2836,
#  'Shark': 7394,
#  'Taco': 8000,
#  'meals': 18525,
#  'shrimp': 22876,
#  'burro': 11067,
#  'stole': 23832,
#  'much': 19026,
#  'flavor': 14944,
#  'snagged': 23204,
#  'bites': 10529,
#  'hubbys': 16686,
#  'burros': 11068,
#  'mmmm': 18855,
#  'delight': 13156,
#  'salsa': 22239,
#  'bar': 10197,
#  'endless': 14137,
#  'really': 21436,
#  'stocked': 23825,
#  'excited': 14385,
#  'strawberry': 23894,
#  'hot': 16583,
#  'fact': 14558,
#  'big': 10473,
#  'wimp': 26287,
#  'horchata': 16548,
#  'handmade': 16093,
#  'throw': 24775,
#  'pecans': 20193,
#  'fruit': 15325,
#  'yummy': 26597,
#  'bonus': 10695,
#  'As': 1108,
#  'wasnt': 26025,
#  'enough': 14173,
#  'win': 26289,
#  'art': 9819,
#  'restaurant': 21861,
#  'sho': 22794,
#  'sucker': 24053,
#  'Mexican': 5462,
#  'folk': 15060,
#  'Frida': 3524,
#  'Kahlo': 4661,
#  'Oprah': 6037,
#  'Theres': 8160,
#  'painting': 19951,
#  'Diego': 2779,
#  'hanging': 16108,
#  'All': 904,
#  'paintings': 19952,
#  'love': 18155,
#  'artist': 9833,
#  'Nobuo': 5840,
#  'shows': 22870,
#  'unique': 25487,
#  'talents': 24373,
#  'Carefully': 1981,
#  'crafted': 12619,
#  'features': 14707,
#  'Start': 7722,
#  'pork': 20697,
#  'belly': 10395,
#  'buns': 11048,
#  'stout': 23868,
#  'Then': 8152,
#  'longer': 18092,
#  'oldish': 19576,
#  'man': 18334,
#  'owns': 19906,
#  'store': 23852,
#  'sweet': 24247,
#  'Perhaps': 6353,
#  'sweeter': 24250,
#  'cookies': 12417,
#  'ice': 16793,
#  'cream': 12655,
#  'lowdown': 18173,
#  'Giant': 3707,
#  'cookie': 12415,
#  'sandwiches': 22284,
#  'super': 24123,
#  'cheap': 11569,
#  'permutations': 20294,
#  'basically': 10254,
#  'snickerdoodle': 23228,
#  'marvelous': 18445,
#  'Wonderful': 8876,
#  'Vietnamese': 8593,
#  'sandwich': 22281,
#  'shoppe': 22817,
#  'Their': 8150,
#  'baguettes': 10123,
#  'oven': 19819,
#  'butter': 11105,
#  'choices': 11728,
#  'modest': 18881,
#  'selection': 22572,
#  'goods': 15703,
#  'along': 9472,
#  'rolls': 22066,
#  'around': 9796,
#  'Bring': 1668,
#  'cash': 11371,
#  'ATM': 773,
#  'card': 11307,
#  'credit': 12680,
#  'cards': 11314,
#  'accepted': 9128,
#  'premises': 20848,
#  'limited': 17949,
#  'time': 24827,
#  'thing': 24707,
#  'going': 15669,
#  'right': 21984,
#  'BBQ': 1205,
#  'chicken': 11646,
#  'long': 18089,
#  'last': 17709,
#  'Probably': 6604,
#  'THE': 7930,
#  'Chicken': 2138,
#  'tried': 25176,
#  'tomato': 24920,
#  'basil': 10256,
#  'soup': 23380,
#  'every': 14323,
#  '5': 479,
#  'stars': 23701,
#  'rate': 21376,
#  'Jasons': 4542,
#  'Deli': 2717,
#  '4': 420,
#  'okay': 19566,
#  'EVER': 2969,
#  'grew': 15861,
#  'shopping': 22822,
#  'los': 18125,
#  'gatos': 15483,
#  'Oakville': 5960,
#  'shock': 22796,
#  'saw': 22361,
#  'world': 26417,
#  'stuff': 23973,
#  'cheese': 11601,
#  'wine': 26301,
#  'tell': 24543,
#  'happy': 16127,
#  'Arizona': 1074,
#  'could': 12530,
#  'dean': 13012,
#  'deluca': 13173,
#  'shouldnt': 22847,
#  'even': 14309,
#  'reviewed': 21928,
#  'kind': 17550,
#  'want': 25980,
#  'keep': 17493,
#  'first': 14871,
#  'went': 26158,
#  'garlic': 15458,
#  'knots': 17594,
#  'favorite': 14683,
#  'course': 12562,
#  'ALOT': 727,
#  'U': 8405,
#  'n': 19115,
#  'check': 11577,
#  'car': 11289,
#  'If': 4356,
#  'u': 25326,
#  'wanna': 25977,
#  'buy': 11120,
#  '1': 13,
#  'Thats': 8143,
#  'wrong': 26472,
#  'move': 19009,
#  'service': 22654,
#  'biggest': 10479,
#  'mistake': 18828,
#  'ur': 25622,
#  'asked': 9859,
#  'girlfriend': 15579,
#  'oil': 19558,
#  'guess': 15957,
#  'ripped': 22005,
#  'lying': 18235,
#  'without': 26348,
#  'fixing': 14898,
#  'problem': 20989,
#  'Might': 5490,
#  'bring': 10908,
#  'accident': 9137,
#  'brand': 10819,
#  'tires': 24874,
#  'timing': 24848,
#  'belt': 10403,
#  'brake': 10814,
#  'pads': 19937,
#  'know': 17595,
#  'whys': 26249,
#  'worst': 26432,
#  'changed': 11522,
#  'months': 18944,
#  'What': 8802,
#  'trashy': 25115,
#  'dealer': 13002,
#  'People': 6338,
#  'somewhere': 23324,
#  'coming': 12081,
#  'ages': 9354,
#  'favorites': 14684,
#  'Elsas': 3059,
#  'burgers': 11050,
#  'dragon': 13723,
#  'wings': 26306,
#  'chinas': 11695,
#  'pepper': 20248,
#  'atmosphere': 9930,
#  'fun': 15368,
#  'display': 13526,
#  'abstract': 9112,
#  'cool': 12424,
#  'boss': 10742,
#  'healthy': 16225,
#  'eating': 13940,
#  'recommended': 21509,
#  'highly': 16381,
#  'skeptical': 23030,
#  'friends': 15274,
#  'convert': 12398,
#  'believers': 10384,
#  'dumplings': 13861,
#  'Onion': 6019,
#  'tart': 24424,
#  'starters': 23708,
#  'Shirataki': 7428,
#  'noodles': 19374,
#  'street': 23901,
#  'tacos': 24336,
#  'entrees': 14207,
#  'also': 9482,
#  'Kaleaid': 4669,
#  'dishes': 13497,
#  'times': 24840,
#  'since': 22968,
#  'never': 19240,
#  'disappointed': 13447,
#  'yoga': 26556,
#  'Kale': 4668,
#  'salad': 22212,
#  'chopped': 11741,
#  'aid': 9379,
#  'Once': 6017,
#  'table': 24313,
#  'uprooted': 25604,
#  'whole': 26235,
#  'plant': 20533,
#  'patio': 20127,
#  'embarrassed': 14072,
#  'date': 12962,
#  'Ever': 3143,
#  'careful': 11320,
#  'arms': 9788,
#  'quite': 21292,
#  'clumsy': 11945,
#  'sometimes': 23322,
#  'NOT': 5713,
#  'banned': 10190,
#  'clumsiness': 11944,
#  'think': 24718,
#  'live': 18022,
#  'True': 8350,
#  'Food': 3443,
#  'Disclaimer': 2803,
#  'charming': 11555,
#  'homes': 16494,
#  'repurposed': 21789,
#  'restaurants': 21865,
#  'certain': 11471,
#  'colored': 12041,
#  'opinion': 19677,
#  'Cibo': 2216,
#  'lunch': 18207,
#  'unknowingly': 25501,
#  '205': 265,
#  'minutes': 18790,
#  'close': 11905,
#  'served': 22643,
#  'anyway': 9651,
#  'salscicia': 22242,
#  'side': 22907,
#  'perfectly': 20270,
#  'crisp': 12717,
#  'chewy': 11639,
#  'saltimbocca': 22248,
#  'sausage': 22343,
#  'flavorful': 14946,
#  'complimented': 12186,
#  'roasted': 22037,
#  'red': 21528,
#  'onions': 19631,
#  'finished': 14847,
#  'quality': 21243,
#  'mozzarella': 19020,
#  'Really': 6807,
#  'friendly': 15273,
#  'comfortable': 12071,
#  'though': 24741,
#  'bit': 10520,
#  'hang': 16105,
#  'lived': 18023,
#  'nearby': 19178,
#  'Disgusting': 2808,
#  'Had': 3992,
#  'Groupon': 3865,
#  'daughter': 12968,
#  'Very': 8576,
#  'outdated': 19776,
#  'gaudy': 15484,
#  '80s': 617,
#  'style': 23995,
#  'interior': 17177,
#  'feel': 14719,
#  'episode': 14230,
#  'Sopranos': 7604,
#  'simple': 22959,
#  'trying': 25232,
#  'positive': 20725,
#  'employees': 14100,
#  'owners': 19900,
#  'creating': 12667,
#  'Never': 5796,
#  'dealt': 13010,
#  'Discount': 2806,
#  'Tire': 8225,
#  'Phoenix': 6388,
#  'Texas': 8124,
#  'knowing': 17597,
#  'expect': 14435,
#  'pleasantly': 20579,
#  'amount': 9546,
#  'parking': 20050,
#  'front': 15300,
#  'open': 19655,
#  'adequate': 9247,
#  'perimeters': 20280,
#  'There': 8156,
#  'already': 9480,
#  '56': 512,
#  'cars': 11356,
#  'infront': 17037,
#  'see': 22547,
#  'representative': 21778,
#  'guys': 16001,
#  'working': 26409,
#  'busy': 11097,
#  'helping': 16302,
#  'yet': 26548,
#  'saying': 22371,
#  'hello': 16288,
#  'reassuring': 21455,
#  'theyd': 24689,
#  'soon': 23337,
#  'didnt': 13342,
#  'unneccesary': 25516,
#  'helped': 16294,
#  'Wally': 8720,
#  'He': 4075,
#  'inspected': 17113,
#  'plan': 20520,
#  'action': 9201,
#  'gave': 15487,
#  'options': 19696,
#  'headed': 16204,
#  'decision': 13051,
#  'replace': 21762,
#  'checked': 11579,
#  'stock': 23824,
#  'unfortunately': 25459,
#  'BUT': 1273,
#  'called': 11190,
#  'another': 9605,
#  'picked': 20392,
#  'come': 12065,
#  'boys': 10800,
#  'installed': 17122,
#  'Great': 3828,
#  'heafty': 16212,
#  'relief': 21674,
#  'although': 9493,
#  'serviced': 22660,
#  'exactly': 14352,
#  'told': 24913,
#  '45': 448,
#  'min': 18744,
#  'apologized': 9669,
#  'need': 19196,
#  '2nd': 335,
#  'sorry': 23363,
#  'forgot': 15138,
#  'name': 19134,
#  'professional': 21021,
#  'recommend': 21506,
#  'bringing': 10909,
#  'future': 15405,
#  'definitely': 13112,
#  'TIP': 7954,
#  'make': 18300,
#  'appointment': 9721,
#  'online': 19634,
#  'walkins': 25956,
#  'believe': 10381,
#  'helps': 16304,
#  'manage': 18335,
#  'customers': 12868,
#  'easier': 13918,
#  'benefits': 10415,
#  'eaten': 13932,
#  'none': 19349,
#  'night': 19278,
#  'Service': 7369,
#  'attentive': 9962,
#  'horrible': 16554,
#  'expectation': 14438,
#  'serve': 22642,
#  'steak': 23747,
#  'par': 20023,
#  'seafood': 22496,
#  'charging': 11546,
#  '39': 395,
#  'bucks': 10991,
#  'ribeye': 21954,
#  'hoping': 16542,
#  '112': 76,
#  'thick': 24695,
#  'cooked': 12413,
#  'Pittsburgh': 6461,
#  '34': 371,
#  'piece': 20416,
#  'meat': 18541,
#  'mostly': 18976,
#  'fat': 14658,
#  'gristle': 15890,
#  'way': 26061,
#  'resembled': 21813,
#  'Style': 7802,
#  'Salad': 7197,
#  'similar': 22954,
#  'Chick': 2137,
#  'Filet': 3360,
#  'Veggies': 8556,
#  'blah': 10554,
#  'Bread': 1645,
#  'basket': 10260,
#  'ample': 9550,
#  'old': 19571,
#  'certainly': 11472,
#  'addition': 9237,
#  'crammed': 12625,
#  'room': 22084,
#  'nuts': 19458,
#  'butts': 11118,
#  '6': 530,
#  'tables': 24317,
#  'listening': 18002,
#  'conversations': 12394,
#  'ranging': 21357,
#  'someones': 23315,
#  'recent': 21477,
#  'bout': 10776,
#  'pinkeye': 20453,
#  'couple': 12556,
#  'elected': 14031,
#  'entirely': 14199,
#  'French': 3510,
#  'showed': 22862,
#  'turned': 25266,
#  'switch': 24279,
#  'suddenly': 24060,
#  'began': 10357,
#  'speaking': 23448,
#  'English': 3083,
#  'pay': 20155,
#  '150': 163,
#  'itll': 17326,
#  'Mortons': 5613,
#  'Maestro': 5231,
#  'steaks': 23751,
#  'perfection': 20267,
#  'half': 16047,
#  'doesnt': 13608,
#  'wind': 26290,
#  'plate': 20545,
#  'Unfortunately': 8469,
#  'lux': 18229,
#  'house': 16615,
#  'nearly': 19182,
#  'poorer': 20676,
#  'coffee': 11994,
#  'pastries': 20106,
#  'music': 19077,
#  'Fred': 3501,
#  'M': 5124,
#  'wont': 26384,
#  'beat': 10310,
#  'dead': 12994,
#  'horse': 16561,
#  'Ill': 4366,
#  'add': 9225,
#  'offer': 19530,
#  'wide': 26254,
#  'deepfried': 13091,
#  'quesadillas': 21257,
#  'Did': 2776,
#  'catch': 11396,
#  'DEEP': 2556,
#  'FRIED': 3243,
#  'QUESADILLAS': 6660,
#  'Alright': 924,
#  'away': 10043,
#  'Yelp': 8970,
#  'fitting': 14887,
#  'comeback': 12066,
#  'review': 21925,
#  'Waffles': 8699,
#  'Yes': 8979,
#  'MFin': 5160,
#  'waffles': 25915,
#  'ghetto': 15549,
#  'Check': 2101,
#  'Has': 4054,
#  'tea': 24485,
#  'nononsense': 19359,
#  'quick': 21275,
#  'Ridiculously': 6914,
#  'Best': 1454,
#  'year': 26511,
#  'fried': 15268,
#  'damn': 12920,
#  'seasoning': 22513,
#  'Now': 5888,
#  'deliciously': 13150,
#  'soft': 23274,
#  'crispy': 12720,
#  'cinammoness': 11784,
#  'cramped': 12626,
#  'matter': 18494,
#  'delivered': 13167,
#  'quiet': 21280,
#  'tunnel': 25259,
#  'vision': 25850,
#  'bite': 10525,
#  'taken': 24362,
#  'orgy': 19741,
#  'goodness': 15698,
#  'requirement': 21799,
#  'Come': 2322,
#  'real': 21426,
#  'early': 13905,
#  'prepared': 20859,
#  'Dont': 2857,
#  'forget': 15131,
#  'Red': 6821,
#  'Velvet': 8557,
#  'cake': 11173,
#  'KoolAid': 4784,
#  'fits': 14884,
#  'fancy': 14616,
#  'Even': 3140,
#  'couldnt': 12532,
#  'stop': 23846,
#  'talking': 24378,
#  'LoLos': 5038,
#  'weeks': 26110,
#  'Shoot': 7437,
#  'later': 17718,
#  'still': 23802,
#  'drooling': 13804,
#  'thinking': 24721,
#  'incredible': 16967,
#  'pasta': 20100,
#  'carbonara': 11302,
#  'tiramisu': 24870,
#  'calamari': 11178,
#  'tomatoes': 24923,
#  'freshest': 15249,
#  'tasted': 24440,
#  'moms': 18918,
#  'attention': 9961,
#  'eat': 13929,
#  'Italian': 4462,
#  'feeling': 14721,
#  'slighted': 23104,
#  'outoftown': 19798,
#  'visitors': 25856,
#  'looking': 18107,
#  'impress': 16890,
#  'owner': 19895,
#  'Jon': 4602,
#  'helpful': 16296,
#  'cares': 11325,
#  'providing': 21114,
#  'dining': 13401,
#  'experience': 14450,
#  'Hes': 4133,
#  'spot': 23564,
#  'recommendations': 21508,
#  'organizes': 19736,
#  'tasting': 24457,
#  'events': 14314,
#  'joining': 17416,
#  'mailing': 18284,
#  'list': 17996,
#  'Facebook': 3256,
#  'page': 19939,
#  'fan': 14611,
#  'Burlingtons': 1756,
#  'deals': 13008,
#  'however': 16633,
#  'return': 21909,
#  'Instead': 4425,
#  'stood': 23843,
#  'line': 17959,
#  '15': 162,
#  'thanks': 24636,
#  'employee': 14099,
#  'Burlington': 1755,
#  'buyingputting': 11125,
#  'layaway': 17745,
#  'three': 24759,
#  'help': 16293,
#  'words': 26401,
#  'except': 14373,
#  'Hold': 4186,
#  'pissed': 20471,
#  'When': 8805,
#  'lady': 17649,
#  'finally': 14816,
#  'done': 13643,
#  'Serious': 7361,
#  'needed': 19198,
#  'work': 26404,
#  'Another': 1002,
#  'meeting': 18584,
#  'laugh': 17727,
#  'Waited': 8706,
#  '20': 245,
#  'beer': 10344,
#  'refilled': 21566,
#  'empty': 14106,
#  'asking': 9861,
#  'refill': 21564,
#  'brunette': 10962,
#  'recognize': 21503,
#  'left': 17808,
#  'sat': 22305,
#  'AT': 768,
#  '925': 668,
#  'ON': 5926,
#  'FRIDAY': 3242,
#  'NIGHT': 5694,
#  'bartender': 10237,
#  'ask': 9857,
#  'Management': 5270,
#  'Pull': 6632,
#  'head': 16200,
#  'ass': 9871,
#  'Sad': 7182,
#  'watch': 26033,
#  'talk': 24374,
#  'Ordered': 6044,
#  'trout': 25208,
#  'shocked': 22797,
#  'lots': 18134,
#  'bones': 10692,
#  'Hmmmmm': 4172,
#  'Well': 8782,
#  'hmmmmmm': 16447,
#  'isnt': 17293,
#  'fish': 14874,
#  'comped': 12139,
#  'church': 11769,
#  'embraces': 14079,
#  'principle': 20961,
#  'Christ': 2194,
#  'Life': 4993,
#  'Church': 2206,
#  'exists': 14421,
#  'lifechanging': 17902,
#  'relationship': 21651,
#  ...}

# %%
reviews_bow = bow_tranformer.transform(X)

# %% [markdown]
# ** Use the fit_transform method on the CountVectorizer object and pass in X (the 'text' column). Save this result by overwriting X.**

# %%
sparsity = 100 * reviews_bow.nnz / (reviews_bow.shape[0] * reviews_bow.shape[1])
print('Sparsity of Bag of Words matrix is {}%'.format(round(sparsity, 2)))

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer()

# %%
tfidf_transformer.fit(reviews_bow)

# %%
reviews_bow_tfidf = tfidf_transformer.transform(reviews_bow)

# %% [markdown]
# ## Training a Model
#
# Time to train a model!

# %%
from sklearn.naive_bayes import MultinomialNB
naive_bayes_model = MultinomialNB()

# %% [markdown]
# ## Pipeline

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer = text_preprocessor)),
    ('tfidf', TfidfTransformer()),
    ('classifier', MultinomialNB())
])

# %% [markdown]
# ## Train Test Split
#
# Let's split our data into training and testing data.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
pipeline.fit(X = X_train, y = y_train)

# %% [markdown]
# ## Predictions and Evaluations
#
# Time to see how our model did!
#
# **Use the predict method off of nb to predict labels from X_test.**

# %%
predictions = pipeline.predict(X_test)

# %% [markdown]
# ** Create a confusion matrix and classification report using these predictions and y_test **

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print('------------- Confusion Matrix -------------\n\t')
print(confusion_matrix(y_true = y_test, y_pred = predictions))
print('\n')
print('------------- Classification Report -------------\n\t')
print(classification_report(y_true = y_test, y_pred = predictions))

# %% [markdown]
# <h2> Without cleaning the reviews <h2>

# %%
new_X = df['text']
new_y = df['stars']

# %%
new_X = CountVectorizer().fit_transform(new_X)

# %%
X_train, X_test, y_train, y_test = train_test_split(new_X, new_y,test_size=0.3,random_state=100)

# %%
naive_bayes_model.fit(X_train, y_train)

# %%
new_predictions = naive_bayes_model.predict(X_test)

# %%
print('------------- Confusion Matrix -------------\n\t')
print(confusion_matrix(y_true = y_test, y_pred = new_predictions))
print('\n')
print('------------- Classification Report -------------\n\t')
print(classification_report(y_true = y_test, y_pred = new_predictions))

# %% [markdown]
# <b> Model performed better with uncleaned reviews </b>
